# %%
from nltk.tokenize import word_tokenize

text = "Mouse and keyboard with monitor."
print(word_tokenize(text))
# Out:
# ['Mouse', 'and', 'keyboard', 'with', 'monitor', '.']

# %%
from nltk.corpus import stopwords

text = "The day is very nice today and might see a rainbow today."

stop_words = set(stopwords.words('english'))
tokens = word_tokenize(text.lower())

filtered_tokens = [word for word in tokens if word not in stop_words]

print(f"Original: {tokens}")
print(f"Filtered: {filtered_tokens}")
# Out:
# Original: ['the', 'day', 'is', 'very', 'nice', 'today', 'and', 'might', 'see', 'a', 'rainbow', 'today', '.']
# Filtered: ['day', 'nice', 'today', 'might', 'see', 'rainbow', 'today', '.']

# %%
# see stemming vs lemmatizing

# %%
# lemmatizing

from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
text = "The boys are running for a better future."
tokens = word_tokenize(text)
lemmatized_words = [lemmatizer.lemmatize(word) for word in tokens]

print(f"original - {text}")
print(f"lemmatized words - {lemmatized_words}")
# Out:
# original - The boys are running for a better future.
# lemmatized words - ['The', 'boy', 'are', 'running', 'for', 'a', 'better', 'future', '.']

# %%
# lemmatizing with pos (part-of-speech)
